# %% [markdown]
# # Assignment 01: Multi-class Classification
# #### Report 蒋纬搏 12111714

# %% [markdown]
# ## CE Loss
# 以下图片讨论了不同γ值时，CELoss在该模型下的训练与测试准确度表现。
#
# ![image.png](attachment:b5d34f1c-2eee-4215-a691-bb4c620aba3f.png)
#
# 交叉熵损失，
# 公式为：$ CELoss(x, y) = - \sum y_i * log(x_i) $
#
# 在多分类问题中表现出了较为优秀的收敛速度和acc准确度。

# %% [markdown]
# ## Focal Loss
# 以下图片讨论了不同γ值时，FocalLoss在该模型下的训练与测试准确度表现。
#
# ### 训练准确度
# ![Focal.png](attachment:6e05be21-dea9-4845-ae57-c64c656117af.png)
#
# ### 测试准确度
# ![download.png](attachment:7750292a-c0d4-4422-8dda-4d9d1f2e35c4.png)
#
# focal loss从样本难易分类角度出发，解决样本非平衡带来的模型训练问题。
# 从样本难易分类角度出发，使得loss聚焦于难分样本，解决了样本少的类别分类准确率不高的问题，当然难分样本不限于样本少的类别，也就是focal loss不仅仅解决了样本非平衡的问题，同样有助于模型的整体性能提高。γ根据真实标签对应的输出概率来决定此次预测loss的权重，概率大说明这是简单任务，权重减小，概率小说明这是困难任务，权重加大。
# 当γ过大时出现了acc总体下降的情况。
# 总体而言根据任务的复杂程度来决定γ的值，能够取得较为优秀的收敛速度。

# %% [markdown]
# ## L1 Loss
# 以下图片讨论了不同γ值时，L1Loss在该模型下的训练与测试准确度表现。
#
# ![L1.png](attachment:3dc1128f-bac9-4533-aa46-d9f21789a5af.png)
#
# L1 Loss在面对较为复杂的分类问题时，效果较差，在该模型中L1 Loss过于简单，效果较差。
# L1 Loss一般被用于回归任务，简单的模型。在解决复杂问题的神经网络中很少使用。
