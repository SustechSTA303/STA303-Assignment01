# %% [markdown]
# # Assignment Report: Analysis of Learning Rate

# %% [markdown]
# ### wwx 12112245

# %% [markdown]
# ## 1. Introduction
# ---
# In this assignment, we conducted experiments to analyze the effect of the initial learning rate on the performance of a deep learning model. The learning rates examined were 1e-1, 1e-2, and 1e-3. The goal was to evaluate how different learning rates impact the model's training process and final accuracy.

# %% [markdown]
# ### 1.1 Experimental Setup
#
# - Dataset: CIFAR-10
# - Model: Convolutional Neural Network (ConvNet)
# - Hyperparameters:
# 	- Batch Size: 128
# 	- Number of Epochs: 30
# 	- Evaluation Interval: 1 epoch
# 	- Optimizer: Stochastic Gradient Descent (SGD) with Momentum
# 		- Initial Learning Rates: 1e-1, 1e-2, 1e-3
# 		- Momentum: 0.9
# 		- Step Size for Learning Rate Decay: 5 epochs
# 		- Gamma for Learning Rate Decay: 0.5

# %% [markdown]
# ### 1.2 Experimental Procedure
#
# 1. We conducted three sets of experiments, each with a different initial learning rate (1e-1, 1e-2, and 1e-3).
# 2. For each experiment, we trained the ConvNet model on the CIFAR-10 dataset for 30 epochs.
# 3. During training, we recorded the training loss, training accuracy, testing loss, and testing accuracy at the end of each epoch.
# 4. We visualized the training and testing curves to analyze the impact of different learning rates.

# %% [markdown]
# ## 2. Experimental Results
# ---

# %% [markdown]
# ### Basic Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Comparison of Results for Different Learning Rates

# %% [markdown]
# #### 2.1 Training Loss

# %%
with open('train_loss1.txt', 'r') as file:
    lines1 = file.readlines()
with open('train_loss2.txt', 'r') as file:
    lines2 = file.readlines()

with open('train_loss3.txt', 'r') as file:
    lines3 = file.readlines()


loss_values1 = [float(line.strip().split()[0]) for line in lines1]
loss_values2 = [float(line.strip().split()[0]) for line in lines2]
loss_values3 = [float(line.strip().split()[0]) for line in lines3]



epochs=np.arange(1, 31)


plt.plot(epochs, loss_values1, label='Loss 1e-1')
plt.plot(epochs, loss_values2, label='Loss 1e-2')
plt.plot(epochs, loss_values3, label='Loss 1e-3')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Curves')
plt.legend() 
plt.savefig('loss1.png')
plt.show()

# %% [markdown]
# #### 2.2 Training Accuracy

# %%
with open('train_acc1.txt', 'r') as file:
    lines1 = file.readlines()
with open('train_acc2.txt', 'r') as file:
    lines2 = file.readlines()

with open('train_acc3.txt', 'r') as file:
    lines3 = file.readlines()


acc_values1 = [float(line.strip().split()[0]) for line in lines1]
acc_values2 = [float(line.strip().split()[0]) for line in lines2]
acc_values3 = [float(line.strip().split()[0]) for line in lines3]



epochs=np.arange(1, 31)


plt.plot(epochs, acc_values1, label='Acc 1e-1')
plt.plot(epochs, acc_values2, label='Acc 1e-2')
plt.plot(epochs, acc_values3, label='Acc 1e-3')

plt.xlabel('Epoch')
plt.ylabel('Acc')
plt.title('Accuracy Curves')
plt.legend()  
plt.savefig('acc1.png')
plt.show()

# %% [markdown]
# #### 2.3 Training F1 Score

# %%
with open('train_f1_1.txt', 'r') as file:
    lines1 = file.readlines()
with open('train_f1_2.txt', 'r') as file:
    lines2 = file.readlines()

with open('train_f1_3.txt', 'r') as file:
    lines3 = file.readlines()


f1_values1 = [float(line.strip().split()[0]) for line in lines1]
f1_values2 = [float(line.strip().split()[0]) for line in lines2]
f1_values3 = [float(line.strip().split()[0]) for line in lines3]



epochs=np.arange(1, 31)


plt.plot(epochs, f1_values1, label='F1 1e-1')
plt.plot(epochs, f1_values2, label='F1 1e-2')
plt.plot(epochs, f1_values3, label='F1 1e-3')

plt.xlabel('Epoch')
plt.ylabel('F1 ')
plt.title('F1 Score Curves')
plt.legend()  
plt.savefig('f1_1.png')
plt.show()

# %% [markdown]
# #### 2.4 Testing Loss

# %%
with open('test_loss1.txt', 'r') as file:
    lines1 = file.readlines()
with open('test_loss2.txt', 'r') as file:
    lines2 = file.readlines()

with open('test_loss3.txt', 'r') as file:
    lines3 = file.readlines()


loss_values1 = [float(line.strip().split()[0]) for line in lines1]
loss_values2 = [float(line.strip().split()[0]) for line in lines2]
loss_values3 = [float(line.strip().split()[0]) for line in lines3]



epochs=np.arange(1, 31)


plt.plot(epochs, loss_values1, label='Loss 1e-1')
plt.plot(epochs, loss_values2, label='Loss 1e-2')
plt.plot(epochs, loss_values3, label='Loss 1e-3')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Curves')
plt.legend()  
plt.savefig('loss2.png')

plt.show()

# %% [markdown]
# #### 2.5 Testing Accuracy

# %%
with open('test_acc1.txt', 'r') as file:
    lines1 = file.readlines()
with open('test_acc2.txt', 'r') as file:
    lines2 = file.readlines()

with open('test_acc3.txt', 'r') as file:
    lines3 = file.readlines()


acc_values1 = [float(line.strip().split()[0]) for line in lines1]
acc_values2 = [float(line.strip().split()[0]) for line in lines2]
acc_values3 = [float(line.strip().split()[0]) for line in lines3]



epochs=np.arange(1, 31)


plt.plot(epochs, acc_values1, label='Acc 1e-1')
plt.plot(epochs, acc_values2, label='Acc 1e-2')
plt.plot(epochs, acc_values3, label='Acc 1e-3')

plt.xlabel('Epoch')
plt.ylabel('Acc')
plt.title('Accuracy Curves')
plt.legend()  
plt.savefig('acc2.png')
plt.show()

# %% [markdown]
# #### 2.6 Testing F1 Score

# %%
with open('test_f1_1.txt', 'r') as file:
    lines1 = file.readlines()
with open('test_f1_2.txt', 'r') as file:
    lines2 = file.readlines()

with open('test_f1_3.txt', 'r') as file:
    lines3 = file.readlines()


f1_values1 = [float(line.strip().split()[0]) for line in lines1]
f1_values2 = [float(line.strip().split()[0]) for line in lines2]
f1_values3 = [float(line.strip().split()[0]) for line in lines3]



epochs=np.arange(1, 31)


plt.plot(epochs, f1_values1, label='F1 1e-1')
plt.plot(epochs, f1_values2, label='F1 1e-2')
plt.plot(epochs, f1_values3, label='F1 1e-3')

plt.xlabel('Epoch')
plt.ylabel('F1 ')
plt.title('F1 Score Curves')
plt.legend()  
plt.savefig('f1_2.png')
plt.show()

# %% [markdown]
# ###  Comparison of Time for Different Learning Rates

# %%
with open('cost time.txt', 'r') as file:
    lines = file.readlines()
time =[float(line.strip().split()[0]) for line in lines]

results = {
    "Learning Rate 1e-1": {
        "Time": time[0],
    },
    "Learning Rate 1e-2": {
        "Time": time[0],
    },
    "Learning Rate 1e-3": {
        "Time": time[0],
    
    }
}
results_df = pd.DataFrame(results)

results_markdown = results_df.to_markdown()
print(results_markdown)
# Out:
# |      |   Learning Rate 1e-1 |   Learning Rate 1e-2 |   Learning Rate 1e-3 |
# |:-----|---------------------:|---------------------:|---------------------:|
# | Time |              233.839 |              233.839 |              233.839 |

# %% [markdown]
# ## 3. Conclusion
# ---

# %% [markdown]
# In this experiment, we trained a deep learning model with different learning rates (1e-1, 1e-2, and 1e-3) and analyzed their impact on model performance. Here are our main conclusions:

# %% [markdown]
# ### 3.1 Impact of Learning Rates on Training Process
#
# We observed that both 1e-1 and 1e-2 converged quickly in comparison to 1e-3. However, the training process for 1e-1 was less stable.In contrast, a smaller learning rate (1e-3) led to a more stable training process but required more time to achieve the same level of accuracy.
#
# ### 3.2 Impact of Learning Rates on Final Performance
# We found that the model with a learning rate of 1e-2 performed best during training, achieving the highest test accuracy and F1 score. The model with a learning rate of 1e-3, while stable, exhibited slightly lower final performance.
#
# ### 3.3 Comparison of Time Costs
# The training times for models with different learning rates were approximately the same, indicating that the choice of learning rate did not significantly affect the training time.
#
# In summary, choosing the appropriate learning rate is crucial for the performance of deep learning models. The optimal choice of learning rate may vary for different tasks and datasets, so it is advisable to adjust and experiment based on specific circumstances. Furthermore, our results suggest that smaller learning rates may contribute to more stable training processes, especially for complex tasks.
